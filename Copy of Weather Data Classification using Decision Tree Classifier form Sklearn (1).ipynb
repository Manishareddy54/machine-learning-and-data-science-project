# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold"><br>
#
# Importing the Necessary Libraries<br></p>

# %% [markdown]
# # Weather Data Classification using scikit-learn

# %% [markdown]
# First we import the necessary libraries of the python for demostration of the Decision Tree Classifier

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Read the data of the weather from the csv file using read_csv function of pandas dataframe

# %%
data = pd.read_csv('./daily_weather.csv')

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold">Daily Weather Data Description</p>
# <br>
# The file **daily_weather.csv** is a comma-separated file that contains weather data.  This data comes from a weather station located in San Diego, California.  The weather station is equipped with sensors that capture weather-related measurements such as air temperature, air pressure, and relative humidity.  Data was collected for a period of three years, from September 2011 to September 2014, to ensure that sufficient data for different seasons and weather conditions is captured.<br><br>
# Let's now check all the columns in the data.

# %% [markdown]
# Know about various columns in the dataset.

# %%
data.columns
# Out:
# Index(['number', 'air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am',
#        'relative_humidity_3pm', 'Unnamed: 11'],
#       dtype='object')

# %%
data.head()
# Out:
#    number  air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 0       0        918.060000     74.822000              271.100000
# 1       1        917.347688     71.403843              101.935179
# 2       2        923.040000     60.638000               51.000000
# 3       3        920.502751     70.138895              198.832133
# 4       4        921.160000     44.294000              277.800000
#
#    avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 0            2.080354              295.400000            2.863283
# 1            2.443009              140.471549            3.533324
# 2           17.067852               63.700000           22.100967
# 3            4.337363              211.203341            5.190045
# 4            1.856660              136.500000            2.863283
#
#    rain_accumulation_9am  rain_duration_9am  relative_humidity_9am  \
# 0                    0.0                0.0              42.420000
# 1                    0.0                0.0              24.328697
# 2                    0.0               20.0               8.900000
# 3                    0.0                0.0              12.189102
# 4                    8.9            14730.0              92.410000
#
#    relative_humidity_3pm  Unnamed: 11
# 0              36.160000          NaN
# 1              19.426597          NaN
# 2              14.460000          NaN
# 3              12.742547          NaN
# 4              76.740000          NaN

# %%
data.tail()
# Out:
#       number  air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 1090    1090            918.90        63.104                   192.9
# 1091    1091            918.71        49.568                   241.6
# 1092    1092            916.60        71.096                   189.3
# 1093    1093            912.60        58.406                   172.7
# 1094    1094            921.53        77.702                    97.1
#
#       avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 1090            3.869906                   207.3            5.212070
# 1091            1.811921                   227.4            2.371156
# 1092            3.064608                   200.8            3.892276
# 1093            3.825167                   189.1            4.764682
# 1094            3.265932                   125.9            4.451511
#
#       rain_accumulation_9am  rain_duration_9am  relative_humidity_9am  \
# 1090                    0.0                0.0                  26.02
# 1091                    0.0                0.0                  90.35
# 1092                    0.0                0.0                  45.59
# 1093                    0.0                0.0                  64.84
# 1094                    0.0                0.0                  14.56
#
#       relative_humidity_3pm  Unnamed: 11
# 1090                  38.18          NaN
# 1091                  73.34          NaN
# 1092                  52.31          NaN
# 1093                  58.28          NaN
# 1094                  15.10          NaN

# %%
data.shape
# Out:
# (1095, 12)

# %% [markdown]
# check the null values

# %%
data.isnull().sum()
# Out:
# number                       0
# air_pressure_9am             3
# air_temp_9am                 5
# avg_wind_direction_9am       4
# avg_wind_speed_9am           3
# max_wind_direction_9am       3
# max_wind_speed_9am           4
# rain_accumulation_9am        6
# rain_duration_9am            3
# relative_humidity_9am        0
# relative_humidity_3pm        0
# Unnamed: 11               1095
# dtype: int64

# %% [markdown]
# Checking is there exists null values in the dataset or not

# %%
data[data.isnull().any(axis=1)].head()
# Out:
#    number  air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 0       0        918.060000     74.822000              271.100000
# 1       1        917.347688     71.403843              101.935179
# 2       2        923.040000     60.638000               51.000000
# 3       3        920.502751     70.138895              198.832133
# 4       4        921.160000     44.294000              277.800000
#
#    avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# 0            2.080354              295.400000            2.863283
# 1            2.443009              140.471549            3.533324
# 2           17.067852               63.700000           22.100967
# 3            4.337363              211.203341            5.190045
# 4            1.856660              136.500000            2.863283
#
#    rain_accumulation_9am  rain_duration_9am  relative_humidity_9am  \
# 0                    0.0                0.0              42.420000
# 1                    0.0                0.0              24.328697
# 2                    0.0               20.0               8.900000
# 3                    0.0                0.0              12.189102
# 4                    8.9            14730.0              92.410000
#
#    relative_humidity_3pm  Unnamed: 11
# 0              36.160000          NaN
# 1              19.426597          NaN
# 2              14.460000          NaN
# 3              12.742547          NaN
# 4              76.740000          NaN

# %%
new_data = data

# %%
del new_data['Unnamed: 11']

# %%
del new_data['number']

# %%
new_data.columns
# Out:
# Index(['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am',
#        'relative_humidity_3pm'],
#       dtype='object')

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold"><br>
#
# Data Cleaning Steps<br><br></p>
#
# We will not need to number for each row so we can clean it.

# %% [markdown]
# Data Cleaning process --> As number column contains unique values which can not help us making any decision

# %%
import math

# %%
mean_press_9am = math.floor(new_data['air_pressure_9am'].mean())
new_data['air_pressure_9am'] = new_data['air_pressure_9am'].fillna(mean_press_9am)

mean_temp_9am = math.floor(new_data['air_temp_9am'].mean())
new_data['air_temp_9am'] = new_data['air_temp_9am'].fillna(mean_temp_9am)

mean_avg_dir = math.floor(new_data['avg_wind_direction_9am'].mean())
new_data['avg_wind_direction_9am'] = new_data['avg_wind_direction_9am'].fillna(mean_avg_dir)

mean_avg_spd = math.floor(new_data['avg_wind_speed_9am'].mean())
new_data['avg_wind_speed_9am'] = new_data['avg_wind_speed_9am'].fillna(mean_avg_spd)

mean_max_dir = math.floor(new_data['max_wind_direction_9am'].mean())
new_data['max_wind_direction_9am'] = new_data['max_wind_direction_9am'].fillna(mean_max_dir)

mean_max_spd = math.floor(new_data['max_wind_speed_9am'].mean())
new_data['max_wind_speed_9am'] = new_data['max_wind_speed_9am'].fillna(mean_max_spd)

mean_rain_acc = math.floor(new_data['rain_accumulation_9am'].mean())
new_data['rain_accumulation_9am'] = new_data['rain_accumulation_9am'].fillna(mean_rain_acc)

mean_rain_dur = math.floor(new_data['rain_duration_9am'].mean())
new_data['rain_duration_9am'] = new_data['rain_duration_9am'].fillna(mean_rain_dur)

new_data.head()
# Out:
#    air_pressure_9am  air_temp_9am  avg_wind_direction_9am  avg_wind_speed_9am  \
# 0        918.060000     74.822000              271.100000            2.080354
# 1        917.347688     71.403843              101.935179            2.443009
# 2        923.040000     60.638000               51.000000           17.067852
# 3        920.502751     70.138895              198.832133            4.337363
# 4        921.160000     44.294000              277.800000            1.856660
#
#    max_wind_direction_9am  max_wind_speed_9am  rain_accumulation_9am  \
# 0              295.400000            2.863283                    0.0
# 1              140.471549            3.533324                    0.0
# 2               63.700000           22.100967                    0.0
# 3              211.203341            5.190045                    0.0
# 4              136.500000            2.863283                    8.9
#
#    rain_duration_9am  relative_humidity_9am  relative_humidity_3pm
# 0                0.0              42.420000              36.160000
# 1                0.0              24.328697              19.426597
# 2               20.0               8.900000              14.460000
# 3                0.0              12.189102              12.742547
# 4            14730.0              92.410000              76.740000

# %%
new_data.isnull().sum()
# Out:
# air_pressure_9am          0
# air_temp_9am              0
# avg_wind_direction_9am    0
# avg_wind_speed_9am        0
# max_wind_direction_9am    0
# max_wind_speed_9am        0
# rain_accumulation_9am     0
# rain_duration_9am         0
# relative_humidity_9am     0
# relative_humidity_3pm     0
# dtype: int64

# %% [markdown]
# ### Extracting independent variable

# %%
X = new_data[['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
       'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
       'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am']]
X.head()
# Out:
#    air_pressure_9am  air_temp_9am  avg_wind_direction_9am  avg_wind_speed_9am  \
# 0        918.060000     74.822000              271.100000            2.080354
# 1        917.347688     71.403843              101.935179            2.443009
# 2        923.040000     60.638000               51.000000           17.067852
# 3        920.502751     70.138895              198.832133            4.337363
# 4        921.160000     44.294000              277.800000            1.856660
#
#    max_wind_direction_9am  max_wind_speed_9am  rain_accumulation_9am  \
# 0              295.400000            2.863283                    0.0
# 1              140.471549            3.533324                    0.0
# 2               63.700000           22.100967                    0.0
# 3              211.203341            5.190045                    0.0
# 4              136.500000            2.863283                    8.9
#
#    rain_duration_9am  relative_humidity_9am
# 0                0.0              42.420000
# 1                0.0              24.328697
# 2               20.0               8.900000
# 3                0.0              12.189102
# 4            14730.0              92.410000

# %% [markdown]
# ### Extracting dependent variable

# %%
new_data['humidity_3pm'] = (new_data['relative_humidity_3pm'] > 25)*1

# %%
y = new_data[['humidity_3pm']]

# %%
y.head()
# Out:
#    humidity_3pm
# 0             1
# 1             0
# 2             0
# 3             0
# 4             1

# %%
X.columns
# Out:
# Index(['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am'],
#       dtype='object')

# %%
y.columns
# Out:
# Index(['humidity_3pm'], dtype='object')

# %%
X.shape
# Out:
# (1095, 9)

# %%
y.shape
# Out:
# (1095, 1)

# %% [markdown]
# Calculatoing the amount of data or say number of rows in the dataset before removing the rows containg null values

# %%
before_rows = data.shape[0]
print(before_rows)
# Out:
# 1095

# %% [markdown]
# Removing the rows which contains the null values

# %%
data = data.dropna()

# %% [markdown]
# Calculatoing the amount of data or say number of rows in the dataset after removing the rows containg null values

# %%
after_rows = data.shape[0]
print(after_rows)
# Out:
# 1095

# %% [markdown]
# Calculate how many rows are deleted which contains the Null Values

# %%
before_rows - after_rows
# Out:
# 0

# %% [markdown]
# Filter the values which contains more than 24.99 relative humidity at 3pm.

# %%
clean_data = data.copy()
clean_data['high_humidity_label'] = (clean_data['relative_humidity_3pm'] >24.99) *1
clean_data['high_humidity_label'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: high_humidity_label, dtype: int64

# %%
y = clean_data[['high_humidity_label']].copy()
y.head()
# Out:
#    high_humidity_label
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %%
clean_data['relative_humidity_3pm'].head()
# Out:
# 0    36.160000
# 1    19.426597
# 2    14.460000
# 3    12.742547
# 4    76.740000
# Name: relative_humidity_3pm, dtype: float64

# %%
y.head()
# Out:
#    high_humidity_label
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold"><br>
#
# Use 9am Sensor Signals as Features to Predict Humidity at 3pm
# <br><br></p>

# %% [markdown]
# Storing all the Morning features other than Humidity at 3 pm in the morning feature

# %%
morning_features = ['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
       'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
       'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am']

# %% [markdown]
# Copying the values from the clean_data dataset to new dataset x which only consist of the Morning Feature Data

# %%
x=clean_data[morning_features].copy()
x.columns
# Out:
# Index(['air_pressure_9am', 'air_temp_9am', 'avg_wind_direction_9am',
#        'avg_wind_speed_9am', 'max_wind_direction_9am', 'max_wind_speed_9am',
#        'rain_accumulation_9am', 'rain_duration_9am', 'relative_humidity_9am'],
#       dtype='object')

# %%
y.columns
# Out:
# Index(['high_humidity_label'], dtype='object')

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold"><br>
#
# Perform Test and Train split
#
# <br><br></p>

# %% [markdown]
# By using train_test_split we have split the data into traing dataset and testing datasets.

# %%
# Splitting the Dataset into the Training set and Test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=10)

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold"><br>
#
# Fit on Train Set
# <br><br></p>

# %% [markdown]
# We have made a classifier for making the Decision Tree and to train the data using this classifier

# %%
from sklearn.tree import DecisionTreeClassifier
humidity_classifier = DecisionTreeClassifier(max_leaf_nodes=10, random_state=1)# Arranging objects into classes

# %%
humidity_classifier.fit(X_train, y_train)

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold"><br>
#
# Predict on Test Set
#
# <br><br></p>

# %% [markdown]
# Using humidity_classifier we have predicted the value for the X_test and stored it to y_predicted

# %%
type(humidity_classifier)
# Out:
# sklearn.tree._classes.DecisionTreeClassifier

# %%
print(len(X_test))
# Out:
# 10

# %%
print(X_train.shape, y_train.shape)
# Out:
# (876, 2) (876,)

# %%
from sklearn.tree import DecisionTreeClassifier

humidity_classifier = DecisionTreeClassifier(random_state=42)

# %%
y_predicted = humidity_classifier.predict(X_test)
y_predicted[:10]

# %%
y_test['humidity_3pm'][:10]

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:blue; font-style:bold"><br>
#
# Measure Accuracy of the Classifier
# <br><br></p>

# %% [markdown]
# Checking our accuracy of the model using accuracy_score function from sklearn metrics which in this case is with around 90% accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predicted)*100
